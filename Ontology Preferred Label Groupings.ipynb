# %% [markdown]
# # Convert some NEO relations to a dict for easy access

# %% [markdown]
# ## 1. Read the prepared tsv file

# %%
import re
import pandas as pd

# Read the TSV file into a DataFrame
df = pd.read_csv('https://www.dropbox.com/s/dk5r022dxsg7k24/NEO%20prepared%20%20%282%29.tsv?dl=1', sep='\t')
df
# Out:
#                                Preferred Label  \
# 0                     swallowing_reflex_absent
# 1                               obesity_morbid
# 2                                     headache
# 3                           homocidal_ideation
# 4                                      aphonia
# ...                                        ...
# 1603                neck_pain_radiating_to_arm
# 1604                              numbness_leg
# 1605                   impaired_hand_dexterity
# 1606                              microcephaly
# 1607  decreased_pain_and_temperature_sensation
#
#                                                Synonyms  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1603                                                NaN
# 1604                                                NaN
# 1605                                                NaN
# 1606  Abnormally small cranium; Abnormally small hea...
# 1607                                                NaN
#
#                            Parents
# 0     cranial_nerve_reflex_finding
# 1                          obesity
# 2                             pain
# 3             threatening_behavior
# 4                  impaired_speech
# ...                            ...
# 1603                pain_radiating
# 1604        numbness_of_lower_limb
# 1605             poor_coordination
# 1606      small_head_circumference
# 1607                   hypesthesia
#
# [1608 rows x 3 columns]

# %% [markdown]
# ## 2. Make a function to handle synonyms as lists
#
# Synonyms are a string of words separated by semicolon, colon or comma. It may contain a period, which is removed. The words of a synonym may be separated by spaces or underscore; normalize to underscore. Return all synonyms in a list.

# %%
def bind_words (s):
  return '_'.join(s.split())

def split_syn (syns):
  if syns:
    return [bind_words(syn.replace('.','')) for syn in (re.split('[;:,] *', syns))]
  else:
    return []

# %% [markdown]
# Test on one synonyms string.

# %%
split_syn('Abnormally small cranium; memory_loss, masked_facies:lack of facial expression.')
# Out:
# ['Abnormally_small_cranium',
#  'memory_loss',
#  'masked_facies',
#  'lack_of_facial_expression']

# %% [markdown]
# Test on all rows that have synonyms.

# %%
for index, row in df.iterrows():
  synonyms = row['Synonyms']
  if not pd.isna(synonyms):
    print(split_syn(synonyms))
# Out:
# ['dyssynergia', 'dystaxia']
# ['constricted_pupil', 'miosis', 'abnormal_non-physiological_constriction_of_the_pupil']
# ['dysfluency']
# ['monoparesis_of_arm']
# ['myoedema']
# ['decreased_touch_on_sole_of_foot']
# ['tardive_dystonia']
# ['optic_papillitis', 'optic_disc_edema', 'optic_disc_swelling', 'choked_disc']
# ['decreased_radial_reflex']
# ['Neck_stiffness', 'Stiff_neck', 'Neck_rigidity', 'cervical_rigidity', 'Neck_rigid']
# ['excessive_tearing', 'watery_eyes', 'epiphora']
# ['hysterical_blindness']
# ['memory_loss']
# ['oculomotor_apraxia']
# ['lack_of_lacrimation', 'lack_of_tears', 'absent_lacrimation']
# ['brisk_radial_reflex', 'brisk_brachioradialis_reflex']
# ['Marcus_Gunn_pupil', 'positive_swinging_flashlight_test']
# ['monoparesis_of_leg']
# ['decortication']
# ['tetraplegia']
# ['pill_rolling_tremor']
# ['difficulty_getting_up']
# ['twelfth_cranial_nerve_finding', 'hypoglossal_nerve_finding']
# ['Any_finding_involving_the_head_such_as_macrocephaly_or_microcephaly']
# ['skin_observation']
# ['decreased_touch_on_hand']
# ['poor_upgaze', 'upgaze_palsy', 'upgaze_weakness']
# ['Abnormal_facial_shape', 'Abnormal_morphology_of_the_face', 'Distinctive_facies', 'Dysmorphic_facial_features', 'Dysmorphic_facies', 'Facial_dysmorphism', 'Unusual_facial_appearance', 'Unusual_facies']
# ['scintillation']
# ['unilateral_blindness']
# ['difficulty_releasing_handgrip']
# ['gaze_preference']
# ['coma_vigil']
# ['poor_memory', 'memory_deficit']
# ['painful_response_to_non_painful_stimulus']
# ['dysdiadochokokinesia', 'impaired_rapid_alternating_movements']
# ['Romberg_sign_present']
# ['Acessory_nerve_disorder']
# ['emotional_indifference', 'affect_blunt', 'restricted_range_of_emotion', 'emotional_blunting']
# ['labile_affect']
# ['graphospasm']
# ['barbers_chair_sign', 'Lhermittes_phenomenom']
# ['decerebration']
# ['impotence']
# ['obtundation', 'stuporous', 'obtunded']
# ['positive_straight_leg_raising_test', 'Laseque_sign']
# ['swollen_glands', 'adenopathy', 'enlarged_lymph_nodes', 'enlarged_glands']
# ['sympathetic_ophthalmoplegia', 'sympathetic_cervical_paralysis', 'oculosympathetic_palsy']
# ['decreased_Achilles_reflex', 'decreased_ankle_jerk']
# ['comatose']
# ['visual_system_disorder']
# ['difficulty_swallowing']
# ['shortness_of_breath']
# ['decreased_touch_on_neck']
# ['hysteria']
# ['gaze_evoked_nystagmus']
# ['non_responsive', 'coma']
# ['weak_intrinsic_hand_muscles']
# ['Normal_Rinne_test']
# ['facial_weakness', 'facial_droop']
# ['daytime_somnulence']
# ['painful_sensitivity_to_sound', 'sounds_seem_unnaturally_loud']
# ['excessive_rebound']
# ['Somniloquism']
# ['clumsy']
# ['festination']
# ['extra_pyramidal_gait']
# ['paralysis_of_both_arms', 'unable_to_move_both_arms']
# ['disequilibrium']
# ['impaired_working_memory', 'impaired_registration']
# ['listless']
# ['total_aphasia']
# ['motor_restlessness']
# ['tactile_sensation_decreased_sensory_level_at_clavicles_T2_dermatome']
# ['myoclonic_jerks']
# ['dyslexia']
# ['extrapyradimal_type_dysarthria']
# ['hyperpathia']
# ['seeeing_double', 'double_vision']
# ['Denial_of_illness']
# ['squint', 'heterotropia']
# ['Dolls_head_reflex_absent', 'Dolls_head_reflex_abnormal']
# ['xerostomia']
# ['decreased_touch_on_arm']
# ['left-right_confusion', 'left-right_disorientation']
# ['achromatopsia']
# ['lack_of_insight', 'defective_insight']
# ['Increased_head_circumference', 'enlarged_head', 'head_size_large', 'large_head', 'Large_skull']
# ['paratonia']
# ['extinction']
# ['Laseque_sign']
# ['cerebellar_dysarthria']
# ['flapping_tremor', 'liver_flap']
# ['combined_flaccid_and_spastic_dysarthria']
# ['glove_anesthesia']
# ['decreased_touch']
# ['verbal_repetition']
# ['drowsy']
# ['right_exophthalmos']
# ['hysterical_seizures']
# ['ipsilatera_absence_of_facial_sweating']
# ['motor_nervous_system_finding']
# ['vagal_nerve_finding']
# ['lower_motor_neuron_type_dysarthria', 'bulbar_type_dysarthria']
# ['bad_balance', 'impaired_balance', 'imbalance']
# ['meningism', 'irritation_meningeal', 'meningeal_irritation', 'meningismus', 'meningitis-like', 'Meningitis-like_reaction', 'pseudomeningitis', 'Pseudomeningitides', 'Reaction', 'Meningitis-Like', 'Syndrome', 'Dupre', 'Syndrome', "Dupre's", "Dupre's_syndrome"]
# ['hemi-inattention', 'sensory_inattention']
# ['echo_speech']
# ['aggression', 'aggressive']
# ['hysterical_paresis']
# ['limb_ataxia']
# ['intention_tremor', 'cerebellar_tremor']
# ['Observation_of_neck_region', 'Finding_of_neck_region']
# ['poor_anal_tone']
# ['pyschomotor_impairment', 'motor_retardation']
# ['impaired_executive_functions']
# ['bilateral_paralysis']
# ['asthenia']
# ['anger', 'angry']
# ['decreased_touch_on_leg_or_foot']
# ['exophthalmos']
# ['unequal_pupils']
# ['visual_perseveration']
# ['lower_limb_amyotrophy']
# ['face_agnosia', 'face_blindness']
# ['muscle_pain']
# ['loss_of_smell']
# ['muscle_hypertonia']
# ['Adie_pupil']
# ['dilated_pupil']
# ['wrist_drop']
# ['masked_facies', 'lack_of_facial_expression', 'poverty_of_facial_expression']
# ['acalculia']
# ['disoriented']
# ['reduced_visual_field', 'narrowed_visual_field']
# ['lack_of_judgment', 'loss_of_judgment']
# ['body_image_agnosia']
# ['bilateral_facial_weakness']
# ['asterognosis']
# ['facial_nerve_finding']
# ['wry_neck']
# ['aphasia-angular_gyrus_syndrome']
# ['restlessness']
# ['INO']
# ['hemianesthesia']
# ['absent_radial_reflex', 'absent_brachioradialis_reflex']
# ['reduced_sense_of_smell', 'impaired_sense_of_smell']
# ["Lhermitte's_sign", 'Barber_chair_sign', "Lhermitte's_phenomenon"]
# ['ocular_dysmetria']
# ['emesis']
# ['mute', 'no_speech']
# ['postural_hypotension']
# ['flaccidity', 'flaccid_tone', 'flaccid_muscle_tone']
# ['hysterical_tremor']
# ['acoustico-vestibular_nerve_disorders']
# ['amyotrophy', 'muscle_wasting']
# ['fatiguability', 'muscle_tire_easily']
# ['trigeminal_nerve_finding']
# ['Abnormal_twitching_movements_of_the_eye']
# ['agitation']
# ['muscle_fasciculation']
# ['astereognosis']
# ['muscle_hypotonia']
# ['dysphasia']
# ['conversion_mutism']
# ['nose_bleed']
# ['olfactory_nerve_disorder', 'first_cranial_nerve_finding', 'cranial_nerve_I_finding']
# ['decreased_patellar_reflex', 'decreased_knee_jerk', 'decreased_quadriceps_reflex']
# ['moon_facies']
# ['Macrocephalus']
# ['elective_mutism']
# ['polyuria']
# ['left_exophthalmos']
# ['Littles_disease']
# ['trouble_walking']
# ['hemineglect']
# ['Abnormally_small_cranium', 'Abnormally_small_head', 'Abnormally_small_skull', 'Decreased_circumference_of_cranium', 'Decreased_size_of_cranium', 'Decreased_size_of_head', 'Decreased_size_of_skull', 'Microcephaly', 'Reduced_head_circumference', 'small_calvarium', 'small_cranium', 'Small_head', "Small_head_circumference'_Small_skull"]

# %% [markdown]
# Make function that lists normalized synonyms from a Synonyms cell value.

# %%
def list_synonyms (synval):
  if pd.isna(synval):
    return []
  else:
    return split_syn(synonyms)

# %% [markdown]
# Test on whole dataframe.

# %%
for index, row in df.head(20).iterrows():
  synonyms = row['Synonyms']
  print(list_synonyms(synonyms))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dyssynergia', 'dystaxia']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['constricted_pupil', 'miosis', 'abnormal_non-physiological_constriction_of_the_pupil']

# %% [markdown]
# ## 3. Make the basic dict based on preferred labels and their properties.
#
# Group the dataframe by parent and aggregate the preferred labels.

# %%
# Group by parent and aggregate the preferred labels
df_grouped = df.groupby('Parents')['Preferred Label'].apply(list).reset_index(name='Preferred Labels')

# Rename the parent column to Common Parents
df_grouped = df_grouped.rename(columns={'parent': 'Common Parents'})

# Save the result as a TSV file
df_grouped.to_csv('neo_grouped.tsv', sep='\t', index=False)

# Print the resulting DataFrame
print(df_grouped)
# Out:
#                      Parents  \
# 0            3rd_nerve_palsy
# 1              Babinski_sign
# 2            Balint_syndrome
# 3               ENT_symptoms
# 4                GI_symptoms
# ..                       ...
# 507  wheelchair_usually_used
# 508                withdrawn
# 509               wrist_pain
# 510         wrist_pain_right
# 511            writers_cramp
#
#                                       Preferred Labels
# 0    [third_nerve_palsy_right_eye, 3rd_nerve_palsy_...
# 1    [extensor_plantar_responses_bilateral, extenso...
# 2      [ocular_apraxia, simultanagnosia, ataxia_optic]
# 3    [drooling, tinnitus, ear_pressure, hyperacusis...
# 4    [hiccoughs, feeding_difficulties, gastroparesi...
# ..                                                 ...
# 507                                 [wheelchair_bound]
# 508                                       [withdrawal]
# 509          [pain_of_right_wrist, pain_of_left_wrist]
# 510                           [wrist_joint_pain_right]
# 511                             [writer_cramp_organic]
#
# [512 rows x 2 columns]

# %% [markdown]
# Make a new dictionary that associates synonyms, parents and brothers with every preferred label.

# %%
# Create an empty dictionary to store the results
preferred_labels_dict = {}

# Iterate through the DataFrame rows
for index, row in df.iterrows():
    parent = row['Parents']
    preferred_label = row['Preferred Label']
    synonyms = row['Synonyms']

    # Check if the preferred label is already in the dictionary
    if preferred_label not in preferred_labels_dict:
        preferred_labels_dict[preferred_label] = {
            'Synonyms': list_synonyms(synonyms),
            'Parents': [parent],
            'Brothers': []
        }
    else:
        # If the preferred label is already in the dictionary, update the 'Parents' list
        preferred_labels_dict[preferred_label]['Parents'].append(parent)

    # Find brothers for the current label
    brothers = df[(df['Parents'] == parent) & (df['Preferred Label'] != preferred_label)]['Preferred Label'].tolist()
    preferred_labels_dict[preferred_label]['Brothers'] = brothers

# Print the created dictionary
for preferred_label, data in list(preferred_labels_dict.items())[:20]:
    print(f"{preferred_label} -> Synonyms: {data['Synonyms']}, Parents: {data['Parents']}, Brothers: {data['Brothers']}")
    #if data['Synonyms']:
      #print(data['Synonyms'])
len(preferred_labels_dict)
# Out:
# swallowing_reflex_absent -> Synonyms: [], Parents: ['cranial_nerve_reflex_finding'], Brothers: ['afferent_pupil_defect', 'absent_direct_light_reflex', 'mesencephalic_light_near_dissociation', 'absent_consensual_reflex', 'decreased_corneal_reflex', 'vestibulo-ocular_reflex_abnormal', 'impaired_gag_reflex']
# obesity_morbid -> Synonyms: [], Parents: ['obesity'], Brothers: ['obesity_truncal', 'obesity_CTCAE']
# headache -> Synonyms: [], Parents: ['pain'], Brothers: ['pain_radiating', 'pain_jaw', 'pain_foot', 'pain_scalp', 'pain_NOS', 'pain_abdominal', 'pain_eye', 'pain_neuropathic', 'tender_temporal_artery', 'pain_chest', 'pain_arm', 'pain_throat', 'chronic_pain_syndrome', 'pain_neck', 'ache', 'pain_burning', 'pain_back', 'pain_diffuse', 'pain_buttock', 'pain_hip', 'radiculopathy', 'arthralgia', 'myalgias', 'pain_leg', 'pain_pelvic', 'pain_ear', 'pain_shoulder', 'pain_sudden_onset', 'pain_stabbing', 'pain_face']
# homocidal_ideation -> Synonyms: [], Parents: ['threatening_behavior'], Brothers: ['outbursts_of_anger', 'harmful_thoughts', 'aggressive_behavior', 'hostility']
# aphonia -> Synonyms: [], Parents: ['impaired_speech'], Brothers: ['dysprosody', 'dysarthria', 'monotonous_speech', 'dysfluency', 'dysphonia', 'speech_limited', 'palilalia', 'echolalia', 'anarthria', 'pressure_of_speech', 'mutism']
# hyperacusis_left_ear -> Synonyms: [], Parents: ['hyperacusis'], Brothers: ['phonophobia', 'hyperacusis_right_ear']
# mania -> Synonyms: [], Parents: ['labile_affect'], Brothers: ['mood_swings']
# paraparesis -> Synonyms: [], Parents: ['weakness_limb'], Brothers: ['weakness_arm', 'weakness_leg', 'quadriparesis', 'monoparesis', 'diplegia', 'hemiparesis']
# poor_school_performance -> Synonyms: [], Parents: ['decreased_school_achievement'], Brothers: []
# ataxia -> Synonyms: ['dyssynergia', 'dystaxia'], Parents: ['cerebellar_signs'], Brothers: []
# syncope_orthostatic -> Synonyms: [], Parents: ['syncope'], Brothers: ['syncopal_episode']
# decreased_pain_and_temperature_sensation_of_hand -> Synonyms: [], Parents: ['decreased_pain_and_temperature_sensation_arm'], Brothers: ['decreased_pain_and_temperature_sensation_of_both_shoulders']
# incontinence -> Synonyms: [], Parents: ['urinary_symptoms'], Brothers: ['urgency_of_micturition', 'sexual_dysfunction', 'nocturia', 'urinary_retention', 'urinary_hesitancy', 'neurogenic_bladder', 'urinary_frequency']
# Anton_syndrome -> Synonyms: [], Parents: ['agnosia_visual'], Brothers: ['prosopagnosia']
# aphasia_Broca -> Synonyms: [], Parents: ['aphasia'], Brothers: ['aphasia_semantic', 'aphasia_Wernicke', 'aphasia_logopenic', 'aphasia_conduction', 'aphasia_subcortical', 'aphasia_mixed', 'aphasia_global', 'aphasia_anomic', 'paraphasia', 'aphasia_transcortical', 'dysphasia']
# dystonia -> Synonyms: [], Parents: ['disease', 'hyperkinesia'], Brothers: ['ballismus', 'oculomasticatory_myorhythmia', 'dyskinesia', 'athetosis', 'chorea', 'choreoathetosis', 'stereotypic_movements']
# absent_right_corneal_reflex -> Synonyms: [], Parents: ['absent_corneal_reflex'], Brothers: ['absent_left_corneal_reflex']
# obsessive_compulsive_disorder -> Synonyms: [], Parents: ['abnormal_behavior'], Brothers: ['uncooperative', 'thought_process_finding', 'wandering', 'threatening_behavior', 'autistic_features', 'conversion_disorder', 'apathy', 'hoarding', 'hyperactive', 'la_belle_indifference', 'abnormal_affect', 'hypochondriasis', 'panic_attack', 'restless', 'low_frustration_tolerance', 'impulsive', 'compulsive_repeating', 'disinhibition']
# uncooperative -> Synonyms: [], Parents: ['abnormal_behavior'], Brothers: ['obsessive_compulsive_disorder', 'thought_process_finding', 'wandering', 'threatening_behavior', 'autistic_features', 'conversion_disorder', 'apathy', 'hoarding', 'hyperactive', 'la_belle_indifference', 'abnormal_affect', 'hypochondriasis', 'panic_attack', 'restless', 'low_frustration_tolerance', 'impulsive', 'compulsive_repeating', 'disinhibition']
# miosis -> Synonyms: ['constricted_pupil', 'miosis', 'abnormal_non-physiological_constriction_of_the_pupil'], Parents: ['pupil_finding'], Brothers: ['Argyll_Robertson_pupil', 'absent_pupil_near_reaction', 'Kayser_Fleisher_ring', 'atrophic_iris', 'anisocoria', 'tonic_pupil', 'mydriasis', 'fixed_dilated_pupil', 'cataract']
# 1607

# %%
print(preferred_labels_dict.get('ataxia'))
print(preferred_labels_dict.get('dystaxia'))
print(preferred_labels_dict.get('dyssynergia'))
# Out:
# {'Synonyms': ['dyssynergia', 'dystaxia'], 'Parents': ['cerebellar_signs'], 'Brothers': []}
# {'Synonyms': [], 'Parents': ['ataxia'], 'Brothers': ['ataxia_truncal', 'ataxia_cerebellar', 'rebound_dysmetria', 'ataxia_sensory', 'ataxia_mild', 'ataxia_appendicular', 'ataxic']}
# None

# %% [markdown]
# ## 4. Make a dict in which synonyms point back to their preferred labels and co-synonyms.
#
# Make a new dict `synonymdict`. For every synonym occurring in a list of synonyms in `preferred_labels_dict`, check if it also occurs as a key there. If it does not occur as a key, make a new entry in `synonymdict` with that synonym as key, and a list with the preferred label plus the other synonyms as value.

# %%
synonymdict = {}

# Iterate through preferred_labels_dict
for preferred_label, data in preferred_labels_dict.items():
    synonyms = data['Synonyms']

    # Iterate through the synonyms for the current preferred label
    for synonym in synonyms:
        if synonym not in synonymdict and synonym not in preferred_labels_dict:
            # Create a new entry with the synonym as the key and a list with the preferred label and other synonyms as the value
            synonymdict[synonym] = {'Synonyms': [preferred_label] + [syn for syn in synonyms if syn != synonym]}

# Print the created synonym dictionary
for synonym, data in list(synonymdict.items())[:20]:
    print(f"{synonym} -> Synonyms: {data['Synonyms']}")
len(synonymdict)
# Out:
# dyssynergia -> Synonyms: ['ataxia', 'dystaxia']
# constricted_pupil -> Synonyms: ['miosis', 'miosis', 'abnormal_non-physiological_constriction_of_the_pupil']
# abnormal_non-physiological_constriction_of_the_pupil -> Synonyms: ['miosis', 'constricted_pupil', 'miosis']
# monoparesis_of_arm -> Synonyms: ['weakness_arm']
# myoedema -> Synonyms: ['myedema']
# decreased_touch_on_sole_of_foot -> Synonyms: ['decreased_tactile_sensation_of_sole_of_foot']
# tardive_dystonia -> Synonyms: ['tardive_dyskinesia']
# optic_papillitis -> Synonyms: ['papilledema', 'optic_disc_edema', 'optic_disc_swelling', 'choked_disc']
# optic_disc_edema -> Synonyms: ['papilledema', 'optic_papillitis', 'optic_disc_swelling', 'choked_disc']
# optic_disc_swelling -> Synonyms: ['papilledema', 'optic_papillitis', 'optic_disc_edema', 'choked_disc']
# choked_disc -> Synonyms: ['papilledema', 'optic_papillitis', 'optic_disc_edema', 'optic_disc_swelling']
# decreased_radial_reflex -> Synonyms: ['impaired_supinator_reflex']
# Neck_stiffness -> Synonyms: ['neck_stiffness', 'Stiff_neck', 'Neck_rigidity', 'cervical_rigidity', 'Neck_rigid']
# Stiff_neck -> Synonyms: ['neck_stiffness', 'Neck_stiffness', 'Neck_rigidity', 'cervical_rigidity', 'Neck_rigid']
# Neck_rigidity -> Synonyms: ['neck_stiffness', 'Neck_stiffness', 'Stiff_neck', 'cervical_rigidity', 'Neck_rigid']
# cervical_rigidity -> Synonyms: ['neck_stiffness', 'Neck_stiffness', 'Stiff_neck', 'Neck_rigidity', 'Neck_rigid']
# Neck_rigid -> Synonyms: ['neck_stiffness', 'Neck_stiffness', 'Stiff_neck', 'Neck_rigidity', 'cervical_rigidity']
# watery_eyes -> Synonyms: ['excessive_tearing', 'excessive_tearing', 'epiphora']
# epiphora -> Synonyms: ['excessive_tearing', 'excessive_tearing', 'watery_eyes']
# oculomotor_apraxia -> Synonyms: ['ocular_apraxia']
# 257

# %%
print(synonymdict.get('dyssynergia'))
# Out:
# {'Synonyms': ['ataxia', 'dystaxia']}

# %% [markdown]
# ## 5. Combine both dicts into one, store and test.

# %%
neocombined = preferred_labels_dict.copy()
neocombined.update(synonymdict)
print(len(neocombined), len(preferred_labels_dict), len(synonymdict))
# Out:
# 1864 1607 257

# %%
print(neocombined.get('ataxia').get('Synonyms'))
print(neocombined.get('dystaxia').get('Synonyms'))
print(neocombined.get('dyssynergia').get('Synonyms'))
# Out:
# ['dyssynergia', 'dystaxia']
# []
# ['ataxia', 'dystaxia']

# %%
import json
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = 'drive/MyDrive/Colab Notebooks/Samuel/Data/'
with open(data_path + 'neo.json','w') as outfile:
  outfile.write(json.dumps(neocombined))

# %%
with open(data_path + 'neo.json') as infile:
  neodict = json.load(infile)

# %%
for key, val in list(neodict.items())[:1600:100]:
    print(f"{key} -> {val}")
# Out:
# swallowing_reflex_absent -> {'Synonyms': [], 'Parents': ['cranial_nerve_reflex_finding'], 'Brothers': ['afferent_pupil_defect', 'absent_direct_light_reflex', 'mesencephalic_light_near_dissociation', 'absent_consensual_reflex', 'decreased_corneal_reflex', 'vestibulo-ocular_reflex_abnormal', 'impaired_gag_reflex']}
# tonic_clonic_seizure -> {'Synonyms': [], 'Parents': ['seizure'], 'Brothers': ['automatisms', 'seizure_generalized', 'myoclonic_seizures', 'staring_episodes_during_seizures', 'absence_seizure', 'seizure_partial', 'infantile_spasms']}
# transient_aphasia -> {'Synonyms': [], 'Parents': ['transient_neurological_symptoms'], 'Brothers': ['transient_limb_weakness', 'transient_amnesia', 'transient_disturbance_of_consciousness', 'temporary_visual_disturbance']}
# inability_to_walk -> {'Synonyms': [], 'Parents': ['difficulty_walking'], 'Brothers': ['wheelchair_usually_used', 'impaired_climbing_stairs', 'uses_cane_walker_or_crutch', 'stumbling', 'general_unsteadiness', 'difficulty_descending_stairs']}
# pain_of_right_wrist -> {'Synonyms': [], 'Parents': ['wrist_pain'], 'Brothers': ['pain_of_left_wrist']}
# decreased_tactile_sensation_of_radial_nerve -> {'Synonyms': [], 'Parents': ['upper_limb_nerve_lesion'], 'Brothers': ['decreased_tactile_sensation_of_ulnar_nerve', 'impaired_pain_and_temperature_of_radial_nerve', 'impaired_pain_and_temperature_sensation_ulnar_nerve', 'impaired_pain_and_temperature_sensation_median_nerve', 'decreased_tactile_sensation_of_median_nerve']}
# gait_stiff_legged -> {'Synonyms': [], 'Parents': ['gait_spastic'], 'Brothers': ['gait_paraplegic', 'gait_scissor']}
# decreased_speech -> {'Synonyms': [], 'Parents': ['speech_limited'], 'Brothers': []}
# tic_vocal -> {'Synonyms': [], 'Parents': ['tic_motor'], 'Brothers': []}
# palpebral_ptosis -> {'Synonyms': [], 'Parents': ['eyelid_ptosis'], 'Brothers': ['ptosis_bilateral', 'droopy_eyelids', 'ptosis_right_eyelid', 'ptosis_left_eyelid', 'ptosis']}
# gait_wide_based -> {'Synonyms': [], 'Parents': ['gait_ataxic'], 'Brothers': ['gait_clumsy', 'gait_unsteady', 'gait_staggering', 'progressive_gait_ataxia', 'gait_unsteady_wide_based']}
# weakness_hip -> {'Synonyms': [], 'Parents': ['weakness_leg'], 'Brothers': ['weakness_knee', 'weakness_lower_limb', 'weakness_of_left_leg', 'weakness_toe', 'weakness_of_right_leg', 'weakness_ankle', 'weakness_foot']}
# general_unsteadiness -> {'Synonyms': [], 'Parents': ['difficulty_walking'], 'Brothers': ['wheelchair_usually_used', 'inability_to_walk', 'impaired_climbing_stairs', 'uses_cane_walker_or_crutch', 'stumbling', 'difficulty_descending_stairs']}
# pain_pelvic -> {'Synonyms': [], 'Parents': ['pain'], 'Brothers': ['headache', 'pain_radiating', 'pain_jaw', 'pain_foot', 'pain_scalp', 'pain_NOS', 'pain_abdominal', 'pain_eye', 'pain_neuropathic', 'tender_temporal_artery', 'pain_chest', 'pain_arm', 'pain_throat', 'chronic_pain_syndrome', 'pain_neck', 'ache', 'pain_burning', 'pain_back', 'pain_diffuse', 'pain_buttock', 'pain_hip', 'radiculopathy', 'arthralgia', 'myalgias', 'pain_leg', 'pain_ear', 'pain_shoulder', 'pain_sudden_onset', 'pain_stabbing', 'pain_face']}
# color_vision_defect -> {'Synonyms': [], 'Parents': ['impaired_vision'], 'Brothers': ['impaired_visual_acuity', 'low_vision', 'visual_field_defect', 'impaired_color_vision']}
# impaired_gag_reflex -> {'Synonyms': [], 'Parents': ['cranial_nerve_reflex_finding'], 'Brothers': ['swallowing_reflex_absent', 'afferent_pupil_defect', 'absent_direct_light_reflex', 'mesencephalic_light_near_dissociation', 'absent_consensual_reflex', 'decreased_corneal_reflex', 'vestibulo-ocular_reflex_abnormal']}

# %%
print(neodict.get('ataxia').get('Synonyms'))
print(neodict.get('dystaxia').get('Synonyms'))
print(neodict.get('dyssynergia').get('Synonyms'))
# Out:
# ['dyssynergia', 'dystaxia']
# []
# ['ataxia', 'dystaxia']

# %%
def try_synonyms(word, ontodict=neodict):
  val = ontodict.get(word)
  if val:
    return val.get('Synonyms')

# %%
print(try_synonyms('ataxia'))
print(try_synonyms('dystaxia'))
print(try_synonyms('nonexistent'))
# Out:
# ['dyssynergia', 'dystaxia']
# []
# None

# %%
def try_parents(word, ontodict=neodict):
  val = ontodict.get(word)
  if val:
    return val.get('Parents')

# %%
print(try_parents('ataxia'))
print(try_parents('dystaxia'))
print(try_parents('nonexistent'))
# Out:
# ['cerebellar_signs']
# ['ataxia']
# None
